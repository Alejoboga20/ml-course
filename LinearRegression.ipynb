# %% [markdown]
# # Linear Regression

# %% [markdown]
# Let's fabricate some data that shows a roughly linear relationship between page speed and amount purchased:

# %%
# %matplotlib inline
import numpy as np
from pylab import *

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 0.1, 1000)) * 3

scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# As we only have two features, we can keep it simple and just use scipy.state.linregress:

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)

# %% [markdown]
# Not surprisngly, our R-squared value shows a really good fit:

# %%
print('slope: ', slope)
print('intercept: ', intercept)
print('r_value: ', r_value)
print('p_value: ', p_value)
print('std_err: ', std_err)
print('r_value ** 2', r_value ** 2)
# Out:
# slope:  -3.009813657912461
# intercept:  100.04797014979312
# r_value:  -0.9947022651777088
# p_value:  0.0
# std_err:  0.009846125780385953
# r_value ** 2 0.9894325963496649

# %% [markdown]
# Let's use the slope and intercept we got from the regression to plot predicted values vs. observed:

# %%
import matplotlib.pyplot as plt

def predict(x):
    return slope * x + intercept

fitLine = predict(pageSpeeds)

plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitLine, c='r')
plt.show()

# %% [markdown]
# ## Activity

# %% [markdown]
# Try increasing the random variation in the test data, and see what effect it has on the r-squared error value.

# %%
# %matplotlib inline
import numpy as np
from pylab import *

speed = np.random.normal(3.0, 1.0, 1000)
purchases = 100 - (speed + np.random.normal(0, 10, 1000)) * 3 # Augmenting Random Variation

scatter(speed, purchases)

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)
print('slope: ', slope)
print('intercept: ', intercept)
print('r_value: ', r_value)
print('p_value: ', p_value)
print('std_err: ', std_err)
print('r_value ** 2', r_value ** 2)

def new_line(x):
  return intercept + x * slope

fitLine = new_line(speed)

plt.scatter(speed, purchases)
plt.plot(speed, fitLine, c='r')
plt.show()
# Out:
# slope:  -2.9303735668310837
# intercept:  99.62000624976218
# r_value:  -0.6877804842178689
# p_value:  5.377259925555793e-141
# std_err:  0.09790297123583412
# r_value ** 2 0.4730419944709662
